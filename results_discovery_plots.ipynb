# %%
import json
import matplotlib.pyplot as plt
import glob
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import Data Experiments

# %%
baselines_files = sorted(glob.glob("results/baseline_10steps/*.json"), key=os.path.getmtime)
generations = len(baselines_files)

baseline_gd_loss = []
baseline_gd_accuracy = []

baseline_training_time = []
baseline_total_evaluation_time = []
baseline_total_time = []

for baselines_file in baselines_files:
    with open(baselines_file, "r") as f:
        baseline_metric = json.load(f)["metrics"]
        baseline_gd_loss.append(baseline_metric["best_gd_loss"])
        baseline_gd_accuracy.append(baseline_metric["best_gd_accuracy"])
        baseline_training_time.append(baseline_metric["training_time"])
        baseline_total_evaluation_time.append(baseline_metric["total_evaluation_time"])
        baseline_total_time.append(baseline_metric["total_time"])

# %%
exp_1_ga_nn_files = sorted(glob.glob("results/mnist_hybrid_ga/exp_1_cx_08_mut_015/gen*.json"), key=os.path.getmtime)

exp_1_ga_nn_cx_08_mut_015_gd_loss = []
exp_1_ga_nn_cx_08_mut_015_gd_accuracy = []
exp_1_ga_nn_cx_08_mut_015_ga_loss = []
exp_1_ga_nn_cx_08_mut_015_ga_accuracy = []

exp_1_ga_nn_cx_08_mut_015_training_time = []
exp_1_ga_nn_cx_08_mut_015_total_evaluation_time = []
exp_1_ga_nn_cx_08_mut_015_total_time = []

exp_1_ga_nn_cx_08_mut_015_mean_ga_loss = []
exp_1_ga_nn_cx_08_mut_015_std_ga_loss = []
exp_1_ga_nn_cx_08_mut_015_mean_ga_accuracy = []
exp_1_ga_nn_cx_08_mut_015_std_ga_accuracy = []

for ga_nn_file in exp_1_ga_nn_files:
    with open(ga_nn_file, "r") as f:
        ga_nn_metric = json.load(f)["metrics"]
        exp_1_ga_nn_cx_08_mut_015_gd_loss.append(ga_nn_metric["best_gd_loss"])
        exp_1_ga_nn_cx_08_mut_015_gd_accuracy.append(ga_nn_metric["best_gd_accuracy"])
        exp_1_ga_nn_cx_08_mut_015_ga_loss.append(ga_nn_metric["best_ga_loss"])
        exp_1_ga_nn_cx_08_mut_015_ga_accuracy.append(ga_nn_metric["best_ga_accuracy"])

        exp_1_ga_nn_cx_08_mut_015_mean_ga_loss.append(ga_nn_metric["mean_ga_loss"])
        exp_1_ga_nn_cx_08_mut_015_std_ga_loss.append(ga_nn_metric["std_ga_loss"])
        exp_1_ga_nn_cx_08_mut_015_mean_ga_accuracy.append(ga_nn_metric["mean_ga_accuracy"])
        exp_1_ga_nn_cx_08_mut_015_std_ga_accuracy.append(ga_nn_metric["std_ga_accuracy"])

        exp_1_ga_nn_cx_08_mut_015_training_time.append(ga_nn_metric["training_time"])
        exp_1_ga_nn_cx_08_mut_015_total_evaluation_time.append(ga_nn_metric["total_evaluation_time"])
        exp_1_ga_nn_cx_08_mut_015_total_time.append(ga_nn_metric["total_time"])

# %%
exp_2_cx_09_mut_01_ga_nn_files = sorted(glob.glob("results/mnist_hybrid_ga/exp_2_cx_09_mut_01/*.json"), key=os.path.getmtime)

exp_2_ga_nn_cx_09_mut_01_gd_loss = []
exp_2_ga_nn_cx_09_mut_01_gd_accuracy = []
exp_2_ga_nn_cx_09_mut_01_ga_loss = []
exp_2_ga_nn_cx_09_mut_01_ga_accuracy = []

exp_2_ga_nn_cx_09_mut_01_training_time = []
exp_2_ga_nn_cx_09_mut_01_total_evaluation_time = []
exp_2_ga_nn_cx_09_mut_01_total_time = []

for ga_nn_file in exp_2_cx_09_mut_01_ga_nn_files:
    with open(ga_nn_file, "r") as f:
        ga_nn_metric = json.load(f)["metrics"]
        exp_2_ga_nn_cx_09_mut_01_gd_loss.append(ga_nn_metric["best_gd_loss"])
        exp_2_ga_nn_cx_09_mut_01_gd_accuracy.append(ga_nn_metric["best_gd_accuracy"])
        exp_2_ga_nn_cx_09_mut_01_ga_loss.append(ga_nn_metric["best_ga_loss"])
        exp_2_ga_nn_cx_09_mut_01_ga_accuracy.append(ga_nn_metric["best_ga_accuracy"])

        exp_2_ga_nn_cx_09_mut_01_training_time.append(ga_nn_metric["training_time"])
        exp_2_ga_nn_cx_09_mut_01_total_evaluation_time.append(ga_nn_metric["total_evaluation_time"])
        exp_2_ga_nn_cx_09_mut_01_total_time.append(ga_nn_metric["total_time"])

# %%
exp_3_ga_nn_files = sorted(glob.glob("results/mnist_hybrid_ga/exp_3_cx_08_mut_015/gen_*.json"), key=os.path.getmtime)

exp_3_ga_nn_cx_08_mut_015_gd_loss = []
exp_3_ga_nn_cx_08_mut_015_gd_accuracy = []
exp_3_ga_nn_cx_08_mut_015_ga_loss = []
exp_3_ga_nn_cx_08_mut_015_ga_accuracy = []

exp_3_ga_nn_cx_08_mut_015_training_time = []
exp_3_ga_nn_cx_08_mut_015_total_evaluation_time = []
exp_3_ga_nn_cx_08_mut_015_total_time = []

exp_3_ga_nn_cx_08_mut_015_mean_ga_loss = []
exp_3_ga_nn_cx_08_mut_015_std_ga_loss = []
exp_3_ga_nn_cx_08_mut_015_mean_ga_accuracy = []
exp_3_ga_nn_cx_08_mut_015_std_ga_accuracy = []

for ga_nn_file in exp_3_ga_nn_files:
    with open(ga_nn_file, "r") as f:
        ga_nn_metric = json.load(f)["metrics"]
        exp_3_ga_nn_cx_08_mut_015_gd_loss.append(ga_nn_metric["best_gd_loss"])
        exp_3_ga_nn_cx_08_mut_015_gd_accuracy.append(ga_nn_metric["best_gd_accuracy"])
        exp_3_ga_nn_cx_08_mut_015_ga_loss.append(ga_nn_metric["best_ga_loss"])
        exp_3_ga_nn_cx_08_mut_015_ga_accuracy.append(ga_nn_metric["best_ga_accuracy"])

        exp_3_ga_nn_cx_08_mut_015_mean_ga_loss.append(ga_nn_metric["mean_ga_loss"])
        exp_3_ga_nn_cx_08_mut_015_std_ga_loss.append(ga_nn_metric["std_ga_loss"])
        exp_3_ga_nn_cx_08_mut_015_mean_ga_accuracy.append(ga_nn_metric["mean_ga_accuracy"])
        exp_3_ga_nn_cx_08_mut_015_std_ga_accuracy.append(ga_nn_metric["std_ga_accuracy"])

        exp_3_ga_nn_cx_08_mut_015_training_time.append(ga_nn_metric["training_time"])
        exp_3_ga_nn_cx_08_mut_015_total_evaluation_time.append(ga_nn_metric["total_evaluation_time"])
        exp_3_ga_nn_cx_08_mut_015_total_time.append(ga_nn_metric["total_time"])

# %%
exp_4_ga_nn_files = sorted(glob.glob("results/mnist_hybrid_ga/exp_4_cx_08_mut_015/gen_*.json"), key=os.path.getmtime)

exp_4_ga_nn_cx_08_mut_015_gd_loss = []
exp_4_ga_nn_cx_08_mut_015_gd_accuracy = []
exp_4_ga_nn_cx_08_mut_015_ga_loss = []
exp_4_ga_nn_cx_08_mut_015_ga_accuracy = []

exp_4_ga_nn_cx_08_mut_015_training_time = []
exp_4_ga_nn_cx_08_mut_015_total_evaluation_time = []
exp_4_ga_nn_cx_08_mut_015_total_time = []

exp_4_ga_nn_cx_08_mut_015_mean_ga_loss = []
exp_4_ga_nn_cx_08_mut_015_std_ga_loss = []
exp_4_ga_nn_cx_08_mut_015_mean_ga_accuracy = []
exp_4_ga_nn_cx_08_mut_015_std_ga_accuracy = []

for ga_nn_file in exp_4_ga_nn_files:
    with open(ga_nn_file, "r") as f:
        ga_nn_metric = json.load(f)["metrics"]
        exp_4_ga_nn_cx_08_mut_015_gd_loss.append(ga_nn_metric["best_gd_loss"])
        exp_4_ga_nn_cx_08_mut_015_gd_accuracy.append(ga_nn_metric["best_gd_accuracy"])
        exp_4_ga_nn_cx_08_mut_015_ga_loss.append(ga_nn_metric["best_ga_loss"])
        exp_4_ga_nn_cx_08_mut_015_ga_accuracy.append(ga_nn_metric["best_ga_accuracy"])

        exp_4_ga_nn_cx_08_mut_015_mean_ga_loss.append(ga_nn_metric["mean_ga_loss"])
        exp_4_ga_nn_cx_08_mut_015_std_ga_loss.append(ga_nn_metric["std_ga_loss"])
        exp_4_ga_nn_cx_08_mut_015_mean_ga_accuracy.append(ga_nn_metric["mean_ga_accuracy"])
        exp_4_ga_nn_cx_08_mut_015_std_ga_accuracy.append(ga_nn_metric["std_ga_accuracy"])

        exp_4_ga_nn_cx_08_mut_015_training_time.append(ga_nn_metric["training_time"])
        exp_4_ga_nn_cx_08_mut_015_total_evaluation_time.append(ga_nn_metric["total_evaluation_time"])
        exp_4_ga_nn_cx_08_mut_015_total_time.append(ga_nn_metric["total_time"])

# %%
exp_5_ga_nn_files = sorted(glob.glob("results/mnist_hybrid_ga/exp_5_cx_08_mut_015/gen_*.json"), key=os.path.getmtime)

exp_5_ga_nn_cx_08_mut_015_gd_loss = []
exp_5_ga_nn_cx_08_mut_015_gd_accuracy = []
exp
        exp_16_ga_nn_cx_08_mut_015_mean_ga_accuracy.append(ga_nn_metric["mean_ga_accuracy"])
        exp_16_ga_nn_cx_08_mut_015_std_ga_accuracy.append(ga_nn_metric["std_ga_accuracy"])

        exp_16_ga_nn_cx_08_mut_015_training_time.append(ga_nn_metric["training_time"])
        exp_16_ga_nn_cx_08_mut_015_total_evaluation_time.append(ga_nn_metric["total_evaluation_time"])
        exp_16_ga_nn_cx_08_mut_015_total_time.append(ga_nn_metric["total_time"])

# %% [markdown]
# ## Evolution of Accuracy and Loss Plot

# %%
# plt.figure()
fig, axs = plt.subplots(3, 2, figsize=(14, 7))

axs[0, 0].plot(exp_1_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[0, 0].plot(exp_1_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[0, 0].plot(baseline_gd_loss, 'o-')
axs[0, 0].set_title("Evolution of Loss\ncxBlend - alpha=0.5")
axs[0, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[0, 0].grid(True)

axs[0, 1].plot(exp_1_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[0, 1].plot(exp_1_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[0, 1].plot(baseline_gd_accuracy, 'o-')
axs[0, 1].set_title("Evolution of Accuracy\ncxBlend - alpha=0.5")
axs[0, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[0, 1].grid(True)

axs[1, 0].plot(exp_3_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[1, 0].plot(exp_3_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[1, 0].plot(baseline_gd_loss, 'o-')
axs[1, 0].set_title("cxBlend - alpha=0.7")
axs[1, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[1, 0].grid(True)

axs[1, 1].plot(exp_3_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[1, 1].plot(exp_3_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[1, 1].plot(baseline_gd_accuracy, 'o-')
axs[1, 1].set_title("cxBlend - alpha=0.7")
axs[1, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[1, 1].grid(True)

axs[2, 0].plot(exp_4_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[2, 0].plot(exp_4_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[2, 0].plot(baseline_gd_loss, 'o-')
axs[2, 0].set_title("cxBlend - alpha=0.9")
axs[2, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[2, 0].grid(True)

axs[2, 1].plot(exp_4_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[2, 1].plot(exp_4_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[2, 1].plot(baseline_gd_accuracy, 'o-')
axs[2, 1].set_title("cxBlend - alpha=0.9")
axs[2, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[2, 1].grid(True)

fig.supxlabel("Generation")
fig.suptitle("mutGaussian - mu=0, sigma=0.3, indpb=0.1")
plt.tight_layout()
plt.savefig("experiment_plots/cxblend_from_05_to_09_mutGaussian_sigma_01.png", dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(14, 7))

axs[0, 0].plot(exp_8_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[0, 0].plot(exp_8_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[0, 0].plot(baseline_gd_loss, 'o-')
axs[0, 0].set_title("Evolution of Loss\ncxBlend - alpha=0.5")
axs[0, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[0, 0].grid(True)

axs[0, 1].plot(exp_8_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[0, 1].plot(exp_8_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[0, 1].plot(baseline_gd_accuracy, 'o-')
axs[0, 1].set_title("Evolution of Accuracy\ncxBlend - alpha=0.5")
axs[0, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[0, 1].grid(True)

axs[1, 0].plot(exp_9_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[1, 0].plot(exp_9_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[1, 0].plot(baseline_gd_loss, 'o-')
axs[1, 0].set_title("cxBlend - alpha=0.7")
axs[1, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[1, 0].grid(True)

axs[1, 1].plot(exp_9_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[1, 1].plot(exp_9_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[1, 1].plot(baseline_gd_accuracy, 'o-')
axs[1, 1].set_title("cxBlend - alpha=0.7")
axs[1, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[1, 1].grid(True)

axs[2, 0].plot(exp_10_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[2, 0].plot(exp_10_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[2, 0].plot(baseline_gd_loss, 'o-')
axs[2, 0].set_title("cxBlend - alpha=0.9")
axs[2, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[2, 0].grid(True)

axs[2, 1].plot(exp_10_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[2, 1].plot(exp_10_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[2, 1].plot(baseline_gd_accuracy, 'o-')
axs[2, 1].set_title("cxBlend - alpha=0.9")
axs[2, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[2, 1].grid(True)

fig.supxlabel("Generation")
fig.suptitle("mutGaussian - mu=0, sigma=0.3, indpb=0.1")
plt.tight_layout()
plt.savefig("experiment_plots/cxblend_from_05_to_09_mutGaussian_sigma_03.png", dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(14, 7))

axs[0, 0].plot(exp_5_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[0, 0].plot(exp_5_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[0, 0].plot(baseline_gd_loss, 'o-')
axs[0, 0].set_title("Evolution of Loss\ncxSimulatedBinary - eta=10")
axs[0, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[0, 0].grid(True)

axs[0, 1].plot(exp_5_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[0, 1].plot(exp_5_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[0, 1].plot(baseline_gd_accuracy, 'o-')
axs[0, 1].set_title("Evolution of Accuracy\ncxSimulatedBinary - eta=10")
axs[0, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[0, 1].grid(True)

axs[1, 0].plot(exp_6_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[1, 0].plot(exp_6_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[1, 0].plot(baseline_gd_loss, 'o-')
axs[1, 0].set_title("cxSimulatedBinary - eta=20")
axs[1, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[1, 0].grid(True)

axs[1, 1].plot(exp_6_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[1, 1].plot(exp_6_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[1, 1].plot(baseline_gd_accuracy, 'o-')
axs[1, 1].set_title("cxSimulatedBinary - eta=20")
axs[1, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[1, 1].grid(True)

axs[2, 0].plot(exp_7_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[2, 0].plot(exp_7_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[2, 0].plot(baseline_gd_loss, 'o-')
axs[2, 0].set_title("cxSimulatedBinary - eta=30")
axs[2, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[2, 0].grid(True)

axs[2, 1].plot(exp_7_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[2, 1].plot(exp_7_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[2, 1].plot(baseline_gd_accuracy, 'o-')
axs[2, 1].set_title("cxSimulatedBinary - eta=30")
axs[2, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[2, 1].grid(True)

fig.supxlabel("Generation")
fig.suptitle("mutGaussian - mu=0, sigma=0.1, indpb=0.1")
plt.tight_layout()
plt.savefig("experiment_plots/cxSimulatedBinary_eta_from_10_to_30_mutGaussian_sigma_01.png", dpi=300)
plt.show()

# %%
# plt.figure()
fig, axs = plt.subplots(3, 2, figsize=(14, 7))

axs[0, 0].plot(exp_11_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[0, 0].plot(exp_11_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[0, 0].plot(baseline_gd_loss, 'o-')
axs[0, 0].set_title("Evolution of Loss\ncxSimulatedBinary - eta=10")
axs[0, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[0, 0].grid(True)

axs[0, 1].plot(exp_11_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[0, 1].plot(exp_11_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[0, 1].plot(baseline_gd_accuracy, 'o-')
axs[0, 1].set_title("Evolution of Accuracy\ncxSimulatedBinary - eta=10")
axs[0, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[0, 1].grid(True)

axs[1, 0].plot(exp_12_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[1, 0].plot(exp_12_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[1, 0].plot(baseline_gd_loss, 'o-')
axs[1, 0].set_title("cxSimulatedBinary - eta=20")
axs[1, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[1, 0].grid(True)

axs[1, 1].plot(exp_12_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[1, 1].plot(exp_12_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[1, 1].plot(baseline_gd_accuracy, 'o-')
axs[1, 1].set_title("cxSimulatedBinary - eta=20")
axs[1, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[1, 1].grid(True)

axs[2, 0].plot(exp_13_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[2, 0].plot(exp_13_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[2, 0].plot(baseline_gd_loss, 'o-')
axs[2, 0].set_title("cxSimulatedBinary - eta=30")
axs[2, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[2, 0].grid(True)

axs[2, 1].plot(exp_13_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[2, 1].plot(exp_13_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[2, 1].plot(baseline_gd_accuracy, 'o-')
axs[2, 1].set_title("cxSimulatedBinary - eta=30")
axs[2, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[2, 1].grid(True)

fig.suptitle("mutGaussian - mu=0, sigma=0.3, indpb=0.1")
fig.supxlabel("Generation")
plt.tight_layout()
plt.savefig("experiment_plots/cxSimulatedBinary_eta_from_10_to_30_mutGaussian_sigma_03.png", dpi=300)
plt.show()

# %%
# plt.figure()
fig, axs = plt.subplots(3, 2, figsize=(14, 7))

axs[0, 0].plot(exp_14_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[0, 0].plot(exp_14_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[0, 0].plot(baseline_gd_loss, 'o-')
axs[0, 0].set_title("Evolution of Loss\ncxBlend - alpha=0.5")
axs[0, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[0, 0].grid(True)

axs[0, 1].plot(exp_14_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[0, 1].plot(exp_14_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[0, 1].plot(baseline_gd_accuracy, 'o-')
axs[0, 1].set_title("Evolution of Accuracy\ncxBlend - alpha=0.5")
axs[0, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[0, 1].grid(True)

axs[1, 0].plot(exp_15_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[1, 0].plot(exp_15_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[1, 0].plot(baseline_gd_loss, 'o-')
axs[1, 0].set_title("cxBlend - alpha=0.7")
axs[1, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[1, 0].grid(True)

axs[1, 1].plot(exp_15_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[1, 1].plot(exp_15_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[1, 1].plot(baseline_gd_accuracy, 'o-')
axs[1, 1].set_title("cxBlend - alpha=0.7")
axs[1, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[1, 1].grid(True)

axs[2, 0].plot(exp_16_ga_nn_cx_08_mut_015_gd_loss, 'o-')
axs[2, 0].plot(exp_16_ga_nn_cx_08_mut_015_ga_loss, 'o-')
axs[2, 0].plot(baseline_gd_loss, 'o-')
axs[2, 0].set_title("cxBlend - alpha=0.9")
axs[2, 0].legend(["GD Loss", "GA Loss", "Baseline Loss"])
axs[2, 0].grid(True)

axs[2, 1].plot(exp_16_ga_nn_cx_08_mut_015_gd_accuracy, 'o-')
axs[2, 1].plot(exp_16_ga_nn_cx_08_mut_015_ga_accuracy, 'o-')
axs[2, 1].plot(baseline_gd_accuracy, 'o-')
axs[2, 1].set_title("cxBlend - alpha=0.9")
axs[2, 1].legend(["GD Accuracy", "GA Accuracy", "Baseline Accuracy"])
axs[2, 1].grid(True)

fig.suptitle("mutPolynomialBounded - eta=15, indpb=0.1, low=-1., up=1.,")
fig.supxlabel("Generation")
plt.tight_layout()
plt.savefig("experiment_plots/cxBlend_alpha_from_05_to_09_mutPolynomialBounded.png", dpi=300)
plt.show()

# %%
exp_16_ga_nn_cx_08_mut_015_ga_accuracy
# Out:
# [0.5238853503184714,
#  0.653562898089172,
#  0.7092953821656051,
#  0.7517914012738853,
#  0.7810509554140127,
#  0.8137937898089171,
#  0.7029259554140127,
#  0.7220342356687898,
#  0.685609076433121,
#  0.73328025477707]

# %%
# pd.DataFrame({
#     "Adam": [baseline_gd_accuracy],
#     "Hybrid_experiment_5": [exp_5_ga_nn_cx_08_mut_015_gd_accuracy],
#     "Hybrid_experiment_6": [exp_6_ga_nn_cx_08_mut_015_gd_accuracy],
#     "Hybrid_experiment_7": [exp_7_ga_nn_cx_08_mut_015_gd_accuracy],
#     "Hybrid_experiment_11": [exp_11_ga_nn_cx_08_mut_015_gd_accuracy],
#     "Hybrid_experiment_12": [exp_12_ga_nn_cx_08_mut_015_gd_accuracy],
#     "Hybrid_experiment_13": [exp_13_ga_nn_cx_08_mut_015_gd_accuracy],
#     }, )

compare_acc_df = pd.DataFrame(
    [
        baseline_gd_accuracy, exp_5_ga_nn_cx_08_mut_015_gd_accuracy, exp_6_ga_nn_cx_08_mut_015_gd_accuracy,
        exp_7_ga_nn_cx_08_mut_015_gd_accuracy, exp_11_ga_nn_cx_08_mut_015_gd_accuracy, exp_12_ga_nn_cx_08_mut_015_gd_accuracy,
        exp_13_ga_nn_cx_08_mut_015_gd_accuracy,
    ],
    index=[
        "Adam", "Hybrid_experiment_5", "Hybrid_experiment_6",
        "Hybrid_experiment_7", "Hybrid_experiment_11", "Hybrid_experiment_12",
        "Hybrid_experiment_13",
    ]
)
compare_acc_df
# for column in compare_acc_df.columns:
#     print(compare_acc_df[compare_acc_df[column] == compare_acc_df[column].max()].index)
# Out:
#                              0         1         2         3         4  \
# Adam                  0.533937  0.668093  0.723428  0.759952  0.780454
# Hybrid_experiment_5   0.566282  0.725418  0.780255  0.811604  0.826632
# Hybrid_experiment_6   0.566282  0.726911  0.779658  0.810311  0.824343
# Hybrid_experiment_7   0.566282  0.724821  0.785928  0.808121  0.824244
# Hybrid_experiment_11  0.566282  0.725418  0.780255  0.807325  0.825438
# Hybrid_experiment_12  0.566282  0.726911  0.779658  0.810709  0.826533
# Hybrid_experiment_13  0.566282  0.724821  0.785928  0.809216  0.826632
#
#                              5         6         7         8         9
# Adam                  0.798567  0.808718  0.822850  0.834196  0.843850
# Hybrid_experiment_5   0.834494  0.850916  0.838177  0.845840  0.853205
# Hybrid_experiment_6   0.835490  0.827926  0.831409  0.847631  0.852508
# Hybrid_experiment_7   0.835689  0.822751  0.832404  0.847930  0.853304
# ...

# %% [markdown]
# ## Evolution of Total Time

# %%
fig, ax = plt.subplots()

y1 = map(lambda x: round(x, 2), exp_1_ga_nn_cx_08_mut_015_total_time)
y3 = map(lambda x: round(x, 2), exp_3_ga_nn_cx_08_mut_015_total_time)
y5 = map(lambda x: round(x, 2), exp_5_ga_nn_cx_08_mut_015_total_time)
y6 = map(lambda x: round(x, 2), exp_6_ga_nn_cx_08_mut_015_total_time)
y2 = map(lambda x: round(x, 2), baseline_total_time)

ax.plot(exp_1_ga_nn_cx_08_mut_015_total_time, 'o-')
# Add annotations
# for i, (xi, yi) in enumerate(zip(range(generations), y1)):
#     plt.annotate(
#         f'{yi}', (xi, yi),
#         textcoords="offset points",
#         xytext=(0, 10),
#         ha='center'
#     )

ax.plot(exp_3_ga_nn_cx_08_mut_015_total_time, 'o-')
# Add annotations
# for i, (xi, yi) in enumerate(zip(range(generations), y3)):
#     plt.annotate(
#         f'{yi}', (xi, yi),
#         textcoords="offset points",
#         xytext=(0, 10),
#         ha='center'
#     )

ax.plot(exp_5_ga_nn_cx_08_mut_015_total_time, 'o-')
# Add annotations
# for i, (xi, yi) in enumerate(zip(range(generations), y5)):
#     plt.annotate(
#         f'{yi}', (xi, yi),
#         textcoords="offset points",
#         xytext=(0, 10),
#         ha='center'
#     )

ax.plot(exp_6_ga_nn_cx_08_mut_015_total_time, 'o-')

ax.plot(baseline_total_time, 'o-')
for i, (xi, yi) in enumerate(zip(range(generations), y2)):
    plt.annotate(
        f'{yi}', (xi, yi),
        textcoords="offset points",
        xytext=(0, 10),
        ha='center'
    )


plt.title("Evolution of Total Time")
plt.xlabel("Generation")
plt.ylabel("Total Time / Generation")
plt.legend(["Total Time GA And GD exp1", "Total Time GA And GD exp3", "Total Time GA And GD exp5",  "Total Time GA And GD exp6", "Total Time GD",])
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

width = 0.25  # the width of the bars
multiplier = 0
x = np.arange(generations)
y1 = map(lambda x: round(x, 2), exp_1_ga_nn_cx_08_mut_015_total_time)
y2 = map(lambda x: round(x, 2), baseline_total_time)

time_metrics = {
    "Total Time GA And GD": list(y1),
    "Total Time GD": list(y2),
}
for attribute, measurement in time_metrics.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set(xlabel='Generation', ylabel="Time, sec")
ax.bar_label(rects, padding=3)
ax.set_title("Evolution of Total Time / Generation")
ax.legend(
    loc='best', bbox_to_anchor=( .9, .9)
)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evolution Max and Mean Loss and Accuracy

# %%
fig, axs = plt.subplots(1,2, figsize=(12,6))

axs[0].errorbar(
    range(generations),
    exp_1_ga_nn_cx_08_mut_015_mean_ga_loss,
    exp_1_ga_nn_cx_08_mut_015_std_ga_loss,
    # 'o-',
)
axs[0].plot(exp_1_ga_nn_cx_08_mut_015_ga_loss, 'o-')

axs[0].set(xlabel='Generation', ylabel="Loss")
axs[0].grid(True)
axs[0].legend([ "Best Loss", "Mean Loss",], )

axs[1].errorbar(
    range(generations),
    exp_1_ga_nn_cx_08_mut_015_mean_ga_accuracy,
    exp_1_ga_nn_cx_08_mut_015_std_ga_accuracy,
    # 'o-',
)
axs[1].plot(exp_1_ga_nn_cx_08_mut_015_ga_accuracy,'o-')
axs[1].set(xlabel='Generation', ylabel="Accuracy")
axs[1].grid(True)
axs[1].legend(["Best Accuracy", "Mean Accuracy", ], )


fig.suptitle("Dependence of maximum and average fitness on generation")
plt.tight_layout()
plt.show()
